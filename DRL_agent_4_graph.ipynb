# %%
import gymnasium as gym
import numpy as np
import networkx as nx
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import torch
import time

# Check if MPS is available
mps_available = hasattr(torch.backends, "mps") and torch.backends.mps.is_available()
device = torch.device("mps" if mps_available else "cpu")
print(f"Using device: {device}")

class GraphEnv(gym.Env):
    def __init__(self, num_nodes, max_steps=1000):
        super(GraphEnv, self).__init__()
        self.num_nodes = num_nodes
        self.max_steps = max_steps
        self.current_step = 0
        self.graph = nx.Graph()
        self.action_space = gym.spaces.MultiDiscrete([num_nodes, num_nodes])
        self.observation_space = gym.spaces.Box(low=0, high=1, 
                                                shape=(num_nodes*num_nodes,), 
                                                dtype=np.int32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.graph = nx.Graph()
        self.graph.add_nodes_from(range(self.num_nodes))
        self.current_step = 0
        return self._get_observation(), {}

    def step(self, action):
        self.current_step += 1
        node1, node2 = action
        if node1 != node2:
            if self.graph.has_edge(node1, node2):
                self.graph.remove_edge(node1, node2)
            else:
                self.graph.add_edge(node1, node2)
        
        obs = self._get_observation()
        reward = self._calculate_reward()
        terminated = self._is_terminated()
        truncated = self.current_step >= self.max_steps
        return obs, reward, terminated, truncated, {}

    def _get_observation(self):
        return nx.to_numpy_array(self.graph).flatten()

    def _calculate_reward(self):
        start_time = time.time()
        mis = self.approximate_mis()
        mis_time = time.time() - start_time
        
        # Reward longer MIS computation times
        reward = mis_time * 1000  # Scale up the time for better gradients
        
        # Penalize for very sparse or very dense graphs
        edge_density = self.graph.number_of_edges() / (self.num_nodes * (self.num_nodes - 1) / 2)
        density_penalty = -abs(edge_density - 0.5) * 10  # Favor graphs with ~50% edge density
        
        return reward + density_penalty

    def _is_terminated(self):
        return self.current_step >= self.max_steps

    def approximate_mis(self):
        return nx.maximal_independent_set(self.graph)

def create_env(num_nodes):
    return lambda: GraphEnv(num_nodes)

def train_agent(env, total_timesteps=100000):
    model = PPO("MlpPolicy", env, verbose=1, 
                learning_rate=0.0003, 
                n_steps=2048, 
                batch_size=64, 
                n_epochs=10, 
                gamma=0.99, 
                gae_lambda=0.95, 
                clip_range=0.2, 
                ent_coef=0.01,
                device=device)
    
    model.learn(total_timesteps=total_timesteps)
    return model

def generate_graph_with_visualization(model, env, delay=0.5):
    obs, _ = env.reset()
    done = False
    step = 0
    
    plt.figure(figsize=(10, 8))
    
    while not done:
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        
        graph = env.envs[0].graph
        mis = nx.maximal_independent_set(graph)
        
        # Visualize the current state of the graph
        plt.clf()
        pos = nx.spring_layout(graph)
        nx.draw(graph, pos, with_labels=True, node_color='lightblue', node_size=700)
        nx.draw_networkx_nodes(graph, pos, nodelist=mis, node_color='red', node_size=800)
        
        edge_labels = {(u, v): f'{u}-{v}' for u, v in graph.edges()}
        nx.draw_networkx_edge_labels(graph, pos, edge_labels=edge_labels, font_size=8)
        
        plt.title(f"Graph Generation Step {step}\nNodes: {graph.number_of_nodes()}, Edges: {graph.number_of_edges()}, MIS size: {len(mis)}")
        
        clear_output(wait=True)
        display(plt.gcf())
        
        plt.pause(delay)
        step += 1
    
    plt.close()
    return graph

def analyze_graph(graph):
    mis = nx.maximal_independent_set(graph)
    print(f"Nodes: {graph.number_of_nodes()}")
    print(f"Edges: {graph.number_of_edges()}")
    print(f"MIS size: {len(mis)}")
    print(f"Average clustering coefficient: {nx.average_clustering(graph)}")
    print(f"Is connected: {nx.is_connected(graph)}")

# Main execution
if __name__ == "__main__":
    NUM_NODES = 30
    env = DummyVecEnv([create_env(NUM_NODES)])
    
    print("Training agent...")
    model = train_agent(env, total_timesteps=200000)
    
    print("Generating graph with visualization...")
    final_graph = generate_graph_with_visualization(model, env)
    
    print("Analyzing generated graph:")
    analyze_graph(final_graph)
# Out:
# Using device: mps
# Training agent...
# Using mps device
# -----------------------------
# | time/              |      |
# |    fps             | 142  |
# |    iterations      | 1    |
# |    time_elapsed    | 14   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 2           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010183027 |
# |    clip_fraction        | 0.0918      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.8        |
# |    explained_variance   | 0.00621     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 281         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0349     |
# |    value_loss           | 518         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 118        |
# |    iterations           | 3          |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01263633 |
# |    clip_fraction        | 0.116      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.79      |
# |    explained_variance   | 0.0281     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 143        |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0404    |
# |    value_loss           | 449        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 4           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012378547 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.78       |
# |    explained_variance   | 0.175       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 142         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0412     |
# |    value_loss           | 444         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 5           |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014953819 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.78       |
# |    explained_variance   | 0.0846      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 91          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0503     |
# |    value_loss           | 341         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 6           |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.016507883 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.77       |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 149         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.05       |
# |    value_loss           | 408         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 7           |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.017009959 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.77       |
# |    explained_variance   | 0.353       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 192         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0525     |
# |    value_loss           | 360         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 8          |
# |    time_elapsed         | 141        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01812616 |
# |    clip_fraction        | 0.215      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.76      |
# |    explained_variance   | 0.442      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 123        |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0536    |
# |    value_loss           | 313        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 9           |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.018867228 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.76       |
# |    explained_variance   | 0.408       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 170         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0529     |
# |    value_loss           | 279         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 10          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.021161124 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.75       |
# |    explained_variance   | 0.503       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 96.7        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0547     |
# |    value_loss           | 232         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 11          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.018611602 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.74       |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.2        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0495     |
# |    value_loss           | 262         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 12          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.021045033 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.74       |
# |    explained_variance   | 0.562       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 105         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0595     |
# |    value_loss           | 231         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 13          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.025022114 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.73       |
# |    explained_variance   | 0.649       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.4        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0602     |
# |    value_loss           | 174         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 14          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.025139906 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.73       |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.2        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0586     |
# |    value_loss           | 160         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 15          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.025776181 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.72       |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0569     |
# |    value_loss           | 88.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 16          |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.024759442 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.71       |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.5        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.056      |
# |    value_loss           | 103         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 17          |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.023406845 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.71       |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.7        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0535     |
# |    value_loss           | 151         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 18          |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.022005094 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.71       |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 109         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0512     |
# |    value_loss           | 158         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 19          |
# |    time_elapsed         | 344         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.025684118 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.69       |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39          |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0587     |
# |    value_loss           | 92.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 20         |
# |    time_elapsed         | 363        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.02511986 |
# |    clip_fraction        | 0.281      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.69      |
# |    explained_variance   | 0.777      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 33.8       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0568    |
# |    value_loss           | 93         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 21          |
# |    time_elapsed         | 380         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.024492562 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.7        |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0517     |
# |    value_loss           | 81.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 22         |
# |    time_elapsed         | 399        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.02578891 |
# |    clip_fraction        | 0.274      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.68      |
# |    explained_variance   | 0.755      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 24.6       |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0568    |
# |    value_loss           | 68.5       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 23         |
# |    time_elapsed         | 417        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.02206882 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.67      |
# |    explained_variance   | 0.876      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 44.5       |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0542    |
# |    value_loss           | 157        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 24          |
# |    time_elapsed         | 435         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.022676887 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.66       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.9        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.053      |
# |    value_loss           | 104         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 25         |
# |    time_elapsed         | 453        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.02449014 |
# |    clip_fraction        | 0.256      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.68      |
# |    explained_variance   | 0.863      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 56.2       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0563    |
# |    value_loss           | 96.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 26          |
# |    time_elapsed         | 472         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.024452388 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.67       |
# |    explained_variance   | 0.822       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.6        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0531     |
# |    value_loss           | 61.4        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 112       |
# |    iterations           | 27        |
# |    time_elapsed         | 490       |
# |    total_timesteps      | 55296     |
# | train/                  |           |
# |    approx_kl            | 0.0239425 |
# |    clip_fraction        | 0.242     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.64     |
# |    explained_variance   | 0.865     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 13.4      |
# |    n_updates            | 260       |
# |    policy_gradient_loss | -0.0497   |
# |    value_loss           | 77.5      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 28          |
# |    time_elapsed         | 509         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.025782002 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.66       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.2        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0539     |
# |    value_loss           | 75.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 29          |
# |    time_elapsed         | 526         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.024137177 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.66       |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.3        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0518     |
# |    value_loss           | 82.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 30          |
# |    time_elapsed         | 543         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.027802065 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.63       |
# |    explained_variance   | 0.805       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.2        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0468     |
# |    value_loss           | 36.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 31          |
# |    time_elapsed         | 560         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.022590969 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.63       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.8        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0473     |
# |    value_loss           | 84          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 32          |
# |    time_elapsed         | 578         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.025828764 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.63       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.5        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0516     |
# |    value_loss           | 52.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 33          |
# |    time_elapsed         | 595         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.023531936 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.6        |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.22        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0496     |
# |    value_loss           | 43.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 34          |
# |    time_elapsed         | 612         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.022262128 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.58       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12          |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0488     |
# |    value_loss           | 40.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 35          |
# |    time_elapsed         | 629         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.029812243 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.6        |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.1        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0482     |
# |    value_loss           | 39.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 36          |
# |    time_elapsed         | 647         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.023967555 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.6        |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.4        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0483     |
# |    value_loss           | 35          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 37          |
# |    time_elapsed         | 664         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.025167499 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.62       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.4        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0502     |
# |    value_loss           | 57.1        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 114        |
# |    iterations           | 38         |
# |    time_elapsed         | 681        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.03019041 |
# |    clip_fraction        | 0.29       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.57      |
# |    explained_variance   | 0.888      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.12       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0474    |
# |    value_loss           | 36.3       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 39          |
# |    time_elapsed         | 698         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.023650974 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.6        |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.5        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0472     |
# |    value_loss           | 30.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 40          |
# |    time_elapsed         | 715         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.024057236 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.57       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0486     |
# |    value_loss           | 35.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 114        |
# |    iterations           | 41         |
# |    time_elapsed         | 733        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.02637244 |
# |    clip_fraction        | 0.26       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.56      |
# |    explained_variance   | 0.91       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.56       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.053     |
# |    value_loss           | 22.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 42          |
# |    time_elapsed         | 750         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.025033195 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.56       |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19          |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0513     |
# |    value_loss           | 26.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 43          |
# |    time_elapsed         | 767         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.022709826 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.54       |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.2        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0484     |
# |    value_loss           | 28.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 44          |
# |    time_elapsed         | 784         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.027462043 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.56       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12          |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0447     |
# |    value_loss           | 31.5        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 114        |
# |    iterations           | 45         |
# |    time_elapsed         | 802        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.02888516 |
# |    clip_fraction        | 0.272      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.56      |
# |    explained_variance   | 0.892      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.906      |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0552    |
# |    value_loss           | 24.3       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 46          |
# |    time_elapsed         | 819         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.026491253 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.53       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.3        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0526     |
# |    value_loss           | 24.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 47          |
# |    time_elapsed         | 836         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.023713073 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.49       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.92        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0513     |
# |    value_loss           | 19          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 48          |
# |    time_elapsed         | 854         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.024035364 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.53       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.55        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0482     |
# |    value_loss           | 19.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 49         |
# |    time_elapsed         | 871        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.02799905 |
# |    clip_fraction        | 0.275      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.5       |
# |    explained_variance   | 0.921      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.1       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0525    |
# |    value_loss           | 21.3       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 50          |
# |    time_elapsed         | 889         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.027821932 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.5        |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.655       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0495     |
# |    value_loss           | 13.7        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 51         |
# |    time_elapsed         | 905        |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.02415592 |
# |    clip_fraction        | 0.261      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.53      |
# |    explained_variance   | 0.928      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.73       |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.051     |
# |    value_loss           | 16.7       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 52          |
# |    time_elapsed         | 922         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.032614343 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.52       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3           |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0526     |
# |    value_loss           | 14          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 53         |
# |    time_elapsed         | 939        |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.03038229 |
# |    clip_fraction        | 0.294      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.49      |
# |    explained_variance   | 0.914      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.783      |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.053     |
# |    value_loss           | 11.5       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 54         |
# |    time_elapsed         | 956        |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.02780843 |
# |    clip_fraction        | 0.27       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.45      |
# |    explained_variance   | 0.934      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.2        |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.0491    |
# |    value_loss           | 12.3       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 55         |
# |    time_elapsed         | 973        |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.03133596 |
# |    clip_fraction        | 0.291      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.4       |
# |    explained_variance   | 0.923      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.55       |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.0476    |
# |    value_loss           | 12.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 56          |
# |    time_elapsed         | 990         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.029605877 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.44       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.569       |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0518     |
# |    value_loss           | 15.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 57         |
# |    time_elapsed         | 1007       |
# |    total_timesteps      | 116736     |
# | train/                  |            |
# |    approx_kl            | 0.02708393 |
# |    clip_fraction        | 0.263      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.44      |
# |    explained_variance   | 0.92       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.5        |
# |    n_updates            | 560        |
# |    policy_gradient_loss | -0.051     |
# |    value_loss           | 11.8       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 58          |
# |    time_elapsed         | 1024        |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.031224076 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.41       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.869       |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0554     |
# |    value_loss           | 14.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 59          |
# |    time_elapsed         | 1041        |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.026289877 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.41       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.63        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0519     |
# |    value_loss           | 13.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 60          |
# |    time_elapsed         | 1058        |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.025063097 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.33       |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.58        |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0465     |
# |    value_loss           | 13.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 61          |
# |    time_elapsed         | 1075        |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.026058525 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.34       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.98        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0503     |
# |    value_loss           | 15.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 62          |
# |    time_elapsed         | 1092        |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.026540825 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.38       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.67        |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.0474     |
# |    value_loss           | 11.9        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 116       |
# |    iterations           | 63        |
# |    time_elapsed         | 1109      |
# |    total_timesteps      | 129024    |
# | train/                  |           |
# |    approx_kl            | 0.0248022 |
# |    clip_fraction        | 0.261     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.36     |
# |    explained_variance   | 0.921     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.27      |
# |    n_updates            | 620       |
# |    policy_gradient_loss | -0.0471   |
# |    value_loss           | 14.6      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 64          |
# |    time_elapsed         | 1126        |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.021343734 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.38       |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.81        |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.046      |
# |    value_loss           | 16.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 65          |
# |    time_elapsed         | 1174        |
# |    total_timesteps      | 133120      |
# | train/                  |             |
# |    approx_kl            | 0.026195887 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# ...
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.15       |
# |    n_updates            | 770        |
# |    policy_gradient_loss | -0.054     |
# |    value_loss           | 10.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 79         |
# |    time_elapsed         | 2309       |
# |    total_timesteps      | 161792     |
# | train/                  |            |
# |    approx_kl            | 0.03069975 |
# |    clip_fraction        | 0.287      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.22      |
# |    explained_variance   | 0.911      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.487      |
# |    n_updates            | 780        |
# |    policy_gradient_loss | -0.0507    |
# |    value_loss           | 9.74       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 80          |
# |    time_elapsed         | 2326        |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.029406814 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.26       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.693       |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.0469     |
# |    value_loss           | 10.7        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 81         |
# |    time_elapsed         | 2342       |
# |    total_timesteps      | 165888     |
# | train/                  |            |
# |    approx_kl            | 0.03569503 |
# |    clip_fraction        | 0.284      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.25      |
# |    explained_variance   | 0.919      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.655      |
# |    n_updates            | 800        |
# |    policy_gradient_loss | -0.0483    |
# |    value_loss           | 14.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 82          |
# |    time_elapsed         | 2358        |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.028649343 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.23       |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04        |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.0523     |
# |    value_loss           | 8.8         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 71         |
# |    iterations           | 83         |
# |    time_elapsed         | 2375       |
# |    total_timesteps      | 169984     |
# | train/                  |            |
# |    approx_kl            | 0.03002654 |
# |    clip_fraction        | 0.266      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.18      |
# |    explained_variance   | 0.935      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.955      |
# |    n_updates            | 820        |
# |    policy_gradient_loss | -0.045     |
# |    value_loss           | 9.22       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 71         |
# |    iterations           | 84         |
# |    time_elapsed         | 2391       |
# |    total_timesteps      | 172032     |
# | train/                  |            |
# |    approx_kl            | 0.03316672 |
# |    clip_fraction        | 0.302      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.27      |
# |    explained_variance   | 0.907      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.379      |
# |    n_updates            | 830        |
# |    policy_gradient_loss | -0.0524    |
# |    value_loss           | 10         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 85          |
# |    time_elapsed         | 2407        |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.026934514 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.2        |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.774       |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0484     |
# |    value_loss           | 11.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 86          |
# |    time_elapsed         | 2424        |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.031812195 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.11       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.514       |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0452     |
# |    value_loss           | 10          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 72         |
# |    iterations           | 87         |
# |    time_elapsed         | 2441       |
# |    total_timesteps      | 178176     |
# | train/                  |            |
# |    approx_kl            | 0.02900334 |
# |    clip_fraction        | 0.278      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.18      |
# |    explained_variance   | 0.915      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.533      |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.0497    |
# |    value_loss           | 11.7       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 88          |
# |    time_elapsed         | 2457        |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.027907629 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.12       |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04        |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0449     |
# |    value_loss           | 12.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 89          |
# |    time_elapsed         | 2474        |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.031349704 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.18       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.534       |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0436     |
# |    value_loss           | 12.9        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 73         |
# |    iterations           | 90         |
# |    time_elapsed         | 2491       |
# |    total_timesteps      | 184320     |
# | train/                  |            |
# |    approx_kl            | 0.03369189 |
# |    clip_fraction        | 0.315      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.23      |
# |    explained_variance   | 0.922      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.37       |
# |    n_updates            | 890        |
# |    policy_gradient_loss | -0.0473    |
# |    value_loss           | 9.28       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 74         |
# |    iterations           | 91         |
# |    time_elapsed         | 2507       |
# |    total_timesteps      | 186368     |
# | train/                  |            |
# |    approx_kl            | 0.03601726 |
# |    clip_fraction        | 0.317      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.2       |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.686      |
# |    n_updates            | 900        |
# |    policy_gradient_loss | -0.0524    |
# |    value_loss           | 8.85       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 92          |
# |    time_elapsed         | 2524        |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.026372809 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.21       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.513       |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0473     |
# |    value_loss           | 9.47        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 74         |
# |    iterations           | 93         |
# |    time_elapsed         | 2540       |
# |    total_timesteps      | 190464     |
# | train/                  |            |
# |    approx_kl            | 0.03560753 |
# |    clip_fraction        | 0.317      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.2       |
# |    explained_variance   | 0.923      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.275      |
# |    n_updates            | 920        |
# |    policy_gradient_loss | -0.05      |
# |    value_loss           | 8.6        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 94          |
# |    time_elapsed         | 2557        |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.029038735 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.95       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.409       |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0499     |
# |    value_loss           | 9.62        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 95          |
# |    time_elapsed         | 2573        |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.028474007 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.98       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.824       |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.046      |
# |    value_loss           | 10.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 96          |
# |    time_elapsed         | 2589        |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.034945372 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.09       |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.33        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0478     |
# |    value_loss           | 11.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 97          |
# |    time_elapsed         | 2606        |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.027813464 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.05       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.535       |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.044      |
# |    value_loss           | 10.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 98          |
# |    time_elapsed         | 2622        |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.036822144 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.18       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.622       |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0508     |
# |    value_loss           | 9.22        |
# -----------------------------------------
# Generating graph with visualization...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 143
#     140 model = train_agent(env, total_timesteps=200000)
#     142 print("Generating graph with visualization...")
# --> 143 final_graph = generate_graph_with_visualization(model, env)
#     145 print("Analyzing generated graph:")
#     146 analyze_graph(final_graph)
#
# Cell In[9], line 92, in generate_graph_with_visualization(model, env, delay)
#      91 def generate_graph_with_visualization(model, env, delay=0.5):
# ---> 92     obs, _ = env.reset()
#      93     done = False
#      94     step = 0
#
# ValueError: not enough values to unpack (expected 2, got 1)
