# %%
# !pip install pyvis
# Out:
# Requirement already satisfied: pyvis in /usr/local/python/3.10.13/lib/python3.10/site-packages (0.3.2)
# Requirement already satisfied: ipython>=5.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from pyvis) (8.26.0)
# Requirement already satisfied: jinja2>=2.9.6 in /home/codespace/.local/lib/python3.10/site-packages (from pyvis) (3.1.4)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pyvis) (3.2.2)
# Requirement already satisfied: networkx>=1.11 in /home/codespace/.local/lib/python3.10/site-packages (from pyvis) (3.3)
# Requirement already satisfied: decorator in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (2.18.0)
# Requirement already satisfied: stack-data in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (5.14.3)
# Requirement already satisfied: exceptiongroup in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (1.2.1)
# Requirement already satisfied: typing-extensions>=4.6 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2>=2.9.6->pyvis) (2.1.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/codespace/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/codespace/.local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /home/codespace/.local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.4.1)
# Requirement already satisfied: pure-eval in /home/codespace/.local/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/codespace/.local/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=5.3.0->pyvis) (1.16.0)

# %%
import graphGenerator as gg

# %%
generator = gg.GraphGenerator()

# Generate and visualize an Erdős-Rényi graph
generator.generate_erdos_renyi(n=20, p=0.2)
print(generator.get_graph_info())
generator.visualize_graph("Erdős-Rényi Random Graph")
generator.display_graph_html()
# Out:
# Graph Type: Erdos-Renyi_n20_p0.2
# Number of nodes: 20
# Number of edges: 33
# Average clustering coefficient: 0.0688
# Average shortest path length: 2.5579
#
# Graph plot saved as: graphs/Erdos-Renyi_n20_p0.2_plot.png
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script src="lib/bindings/utils.js"></script>
#             <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/dist/vis-network.min.css" integrity="sha512-WgxfT5LWjfszlPHXRmBWHkV2eceiWTOBvrKCNbdgDYTHrT2AeLCGbF4sZlZw3UMN3WtL0tGUoIAKsu8mllg/XA==" crossorigin="anonymous" referrerpolicy="no-referrer" />
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/vis-network.min.js" integrity="sha512-LnvoEWDFrqGHlHmDD2101OrLcbsfkrzoSpvtSQtxK3RMnRV0eOkhhBN2dXHKRrUU8p2DGRTk35n4O8nWSVe1mQ==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#
#
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#         <link
#           href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/css/bootstrap.min.css"
#           rel="stylesheet"
#           integrity="sha384-eOJMYsd53ii+scO/bJGFsiCZc+5NDVN2yr8+0RDqr0Ql0h+rP48ckxlpbzKgwra6"
#           crossorigin="anonymous"
#         />
#         <script
#           src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/js/bootstrap.bundle.min.js"
#           integrity="sha384-JEW9xMcG8R+pH31jmWH6WWP0WintQrMb4s7ZOdauHnUtxwoG2vI5DkLtS3qm9Ekf"
#           crossorigin="anonymous"
#         ></script>
#
#
#         <center>
#           <h1></h1>
#         </center>
#         <style type="text/css">
#
#              #mynetwork {
#                  width: 100%;
#                  height: 500px;
#                  background-color: #222222;
#                  border: 1px solid lightgray;
#                  position: relative;
#                  float: left;
#              }
#
#
#
#
#
#
#         </style>
#     </head>
#
#
#     <body>
#         <div class="card" style="width: 100%">
#
#
#             <div id="mynetwork" class="card-body"></div>
#         </div>
#
#
#
#
#         <script type="text/javascript">
#
#               // initialize global variables.
#               var edges;
#               var nodes;
#               var allNodes;
#               var allEdges;
#               var nodeColors;
#               var originalNodes;
#               var network;
#               var container;
#               var options, data;
#               var filter = {
#                   item : '',
#                   property : '',
#                   value : []
#               };
#
#
#
#
#
#               // This method is responsible for drawing the graph, returns the drawn network
#               function drawGraph() {
#                   var container = document.getElementById('mynetwork');
#
#
#
#                   // parsing and collecting nodes and edges from the python
#                   nodes = new vis.DataSet([{"color": "#97c2fc", "font": {"color": "white"}, "id": 0, "label": 0, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 1, "label": 1, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 9, "label": 9, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 11, "label": 11, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 13, "label": 13, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 15, "label": 15, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 16, "label": 16, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 19, "label": 19, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 2, "label": 2, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 6, "label": 6, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 12, "label": 12, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 4, "label": 4, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 3, "label": 3, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 7, "label": 7, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 8, "label": 8, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 5, "label": 5, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 10, "label": 10, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 14, "label": 14, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 18, "label": 18, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 17, "label": 17, "shape": "dot", "size": 10}]);
#                   edges = new vis.DataSet([{"from": 0, "to": 1, "width": 1}, {"from": 0, "to": 9, "width": 1}, {"from": 0, "to": 11, "width": 1}, {"from": 0, "to": 13, "width": 1}, {"from": 0, "to": 15, "width": 1}, {"from": 0, "to": 16, "width": 1}, {"from": 0, "to": 19, "width": 1}, {"from": 1, "to": 2, "width": 1}, {"from": 1, "to": 6, "width": 1}, {"from": 1, "to": 12, "width": 1}, {"from": 2, "to": 4, "width": 1}, {"from": 2, "to": 16, "width": 1}, {"from": 3, "to": 7, "width": 1}, {"from": 4, "to": 8, "width": 1}, {"from": 4, "to": 11, "width": 1}, {"from": 5, "to": 8, "width": 1}, {"from": 5, "to": 15, "width": 1}, {"from": 7, "to": 10, "width": 1}, {"from": 7, "to": 13, "width": 1}, {"from": 9, "to": 11, "width": 1}, {"from": 9, "to": 12, "width": 1}, {"from": 9, "to": 16, "width": 1}, {"from": 10, "to": 12, "width": 1}, {"from": 11, "to": 14, "width": 1}, {"from": 11, "to": 18, "width": 1}, {"from": 12, "to": 13, "width": 1}, {"from": 12, "to": 18, "width": 1}, {"from": 13, "to": 14, "width": 1}, {"from": 13, "to": 17, "width": 1}, {"from": 14, "to": 16, "width": 1}, {"from": 14, "to": 19, "width": 1}, {"from": 16, "to": 19, "width": 1}, {"from": 17, "to": 19, "width": 1}]);
#
#                   nodeColors = {};
#                   allNodes = nodes.get({ returnType: "Object" });
#                   for (nodeId in allNodes) {
#                     nodeColors[nodeId] = allNodes[nodeId].color;
#                   }
#                   allEdges = edges.get({ returnType: "Object" });
#                   // adding nodes and edges to the graph
#                   data = {nodes: nodes, edges: edges};
#
#                   var options = {
#     "configure": {
#         "enabled": false
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": true,
#             "type": "dynamic"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "enabled": true,
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
#
#
#
#
#
#
#                   network = new vis.Network(container, data, options);
#
#
#
#
#
#
#
#
#
#
#                   return network;
#
#               }
#               drawGraph();
#         </script>
#     </body>
# </html>

# %%
# Generate and visualize a Barabási-Albert graph
generator.generate_barabasi_albert(n=20, m=2)
print(generator.get_graph_info())
generator.visualize_graph("Barabási-Albert Preferential Attachment Graph")
generator.display_graph_html()
# Out:
# Graph Type: Barabasi-Albert_n20_m2
# Number of nodes: 20
# Number of edges: 36
# Average clustering coefficient: 0.5277
# Average shortest path length: 2.0632
#
# Graph plot saved as: graphs/Barabasi-Albert_n20_m2_plot.png
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script src="lib/bindings/utils.js"></script>
#             <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/dist/vis-network.min.css" integrity="sha512-WgxfT5LWjfszlPHXRmBWHkV2eceiWTOBvrKCNbdgDYTHrT2AeLCGbF4sZlZw3UMN3WtL0tGUoIAKsu8mllg/XA==" crossorigin="anonymous" referrerpolicy="no-referrer" />
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/vis-network.min.js" integrity="sha512-LnvoEWDFrqGHlHmDD2101OrLcbsfkrzoSpvtSQtxK3RMnRV0eOkhhBN2dXHKRrUU8p2DGRTk35n4O8nWSVe1mQ==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#
#
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#         <link
#           href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/css/bootstrap.min.css"
#           rel="stylesheet"
#           integrity="sha384-eOJMYsd53ii+scO/bJGFsiCZc+5NDVN2yr8+0RDqr0Ql0h+rP48ckxlpbzKgwra6"
#           crossorigin="anonymous"
#         />
#         <script
#           src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/js/bootstrap.bundle.min.js"
#           integrity="sha384-JEW9xMcG8R+pH31jmWH6WWP0WintQrMb4s7ZOdauHnUtxwoG2vI5DkLtS3qm9Ekf"
#           crossorigin="anonymous"
#         ></script>
#
#
#         <center>
#           <h1></h1>
#         </center>
#         <style type="text/css">
#
#              #mynetwork {
#                  width: 100%;
#                  height: 500px;
#                  background-color: #222222;
#                  border: 1px solid lightgray;
#                  position: relative;
#                  float: left;
#              }
#
#
#
#
#
#
#         </style>
#     </head>
#
#
#     <body>
#         <div class="card" style="width: 100%">
#
#
#             <div id="mynetwork" class="card-body"></div>
#         </div>
#
#
#
#
#         <script type="text/javascript">
#
#               // initialize global variables.
#               var edges;
#               var nodes;
#               var allNodes;
#               var allEdges;
#               var nodeColors;
#               var originalNodes;
#               var network;
#               var container;
#               var options, data;
#               var filter = {
#                   item : '',
#                   property : '',
#                   value : []
#               };
#
#
#
#
#
#               // This method is responsible for drawing the graph, returns the drawn network
#               function drawGraph() {
#                   var container = document.getElementById('mynetwork');
#
#
#
#                   // parsing and collecting nodes and edges from the python
#                   nodes = new vis.DataSet([{"color": "#97c2fc", "font": {"color": "white"}, "id": 0, "label": 0, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 1, "label": 1, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 2, "label": 2, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 3, "label": 3, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 4, "label": 4, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 6, "label": 6, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 7, "label": 7, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 11, "label": 11, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 13, "label": 13, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 5, "label": 5, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 8, "label": 8, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 9, "label": 9, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 10, "label": 10, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 14, "label": 14, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 15, "label": 15, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 16, "label": 16, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 17, "label": 17, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 19, "label": 19, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 18, "label": 18, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 12, "label": 12, "shape": "dot", "size": 10}]);
#                   edges = new vis.DataSet([{"from": 0, "to": 1, "width": 1}, {"from": 0, "to": 2, "width": 1}, {"from": 0, "to": 3, "width": 1}, {"from": 0, "to": 4, "width": 1}, {"from": 0, "to": 6, "width": 1}, {"from": 0, "to": 7, "width": 1}, {"from": 0, "to": 11, "width": 1}, {"from": 0, "to": 13, "width": 1}, {"from": 1, "to": 3, "width": 1}, {"from": 1, "to": 5, "width": 1}, {"from": 1, "to": 8, "width": 1}, {"from": 3, "to": 4, "width": 1}, {"from": 3, "to": 5, "width": 1}, {"from": 3, "to": 6, "width": 1}, {"from": 3, "to": 8, "width": 1}, {"from": 3, "to": 9, "width": 1}, {"from": 3, "to": 10, "width": 1}, {"from": 3, "to": 11, "width": 1}, {"from": 3, "to": 14, "width": 1}, {"from": 3, "to": 15, "width": 1}, {"from": 3, "to": 16, "width": 1}, {"from": 3, "to": 17, "width": 1}, {"from": 3, "to": 19, "width": 1}, {"from": 4, "to": 10, "width": 1}, {"from": 4, "to": 18, "width": 1}, {"from": 5, "to": 12, "width": 1}, {"from": 6, "to": 7, "width": 1}, {"from": 6, "to": 9, "width": 1}, {"from": 8, "to": 12, "width": 1}, {"from": 8, "to": 14, "width": 1}, {"from": 8, "to": 16, "width": 1}, {"from": 8, "to": 17, "width": 1}, {"from": 9, "to": 13, "width": 1}, {"from": 9, "to": 15, "width": 1}, {"from": 9, "to": 19, "width": 1}, {"from": 12, "to": 18, "width": 1}]);
#
#                   nodeColors = {};
#                   allNodes = nodes.get({ returnType: "Object" });
#                   for (nodeId in allNodes) {
#                     nodeColors[nodeId] = allNodes[nodeId].color;
#                   }
#                   allEdges = edges.get({ returnType: "Object" });
#                   // adding nodes and edges to the graph
#                   data = {nodes: nodes, edges: edges};
#
#                   var options = {
#     "configure": {
#         "enabled": false
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": true,
#             "type": "dynamic"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "enabled": true,
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
#
#
#
#
#
#
#                   network = new vis.Network(container, data, options);
#
#
#
#
#
#
#
#
#
#
#                   return network;
#
#               }
#               drawGraph();
#         </script>
#     </body>
# </html>

# %%
# Generate and visualize a Watts-Strogatz graph
generator.generate_watts_strogatz(n=20, k=4, p=0.1)
print(generator.get_graph_info())
generator.visualize_graph("Watts-Strogatz Small-World Graph")
generator.display_graph_html()
# Out:
# Graph Type: Watts-Strogatz_n20_k4_p0.1
# Number of nodes: 20
# Number of edges: 40
# Average clustering coefficient: 0.4067
# Average shortest path length: 2.5474
# Graph plot saved as: graphs/Watts-Strogatz_n20_k4_p0.1_plot.png
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script src="lib/bindings/utils.js"></script>
#             <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/dist/vis-network.min.css" integrity="sha512-WgxfT5LWjfszlPHXRmBWHkV2eceiWTOBvrKCNbdgDYTHrT2AeLCGbF4sZlZw3UMN3WtL0tGUoIAKsu8mllg/XA==" crossorigin="anonymous" referrerpolicy="no-referrer" />
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/vis-network.min.js" integrity="sha512-LnvoEWDFrqGHlHmDD2101OrLcbsfkrzoSpvtSQtxK3RMnRV0eOkhhBN2dXHKRrUU8p2DGRTk35n4O8nWSVe1mQ==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#
#
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#         <link
#           href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/css/bootstrap.min.css"
#           rel="stylesheet"
#           integrity="sha384-eOJMYsd53ii+scO/bJGFsiCZc+5NDVN2yr8+0RDqr0Ql0h+rP48ckxlpbzKgwra6"
#           crossorigin="anonymous"
#         />
#         <script
#           src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/js/bootstrap.bundle.min.js"
#           integrity="sha384-JEW9xMcG8R+pH31jmWH6WWP0WintQrMb4s7ZOdauHnUtxwoG2vI5DkLtS3qm9Ekf"
#           crossorigin="anonymous"
#         ></script>
#
#
#         <center>
#           <h1></h1>
#         </center>
#         <style type="text/css">
#
#              #mynetwork {
#                  width: 100%;
#                  height: 500px;
#                  background-color: #222222;
#                  border: 1px solid lightgray;
#                  position: relative;
#                  float: left;
#              }
#
#
#
#
#
#
#         </style>
#     </head>
#
#
#     <body>
#         <div class="card" style="width: 100%">
#
#
#             <div id="mynetwork" class="card-body"></div>
#         </div>
#
#
#
#
#         <script type="text/javascript">
#
#               // initialize global variables.
#               var edges;
#               var nodes;
#               var allNodes;
#               var allEdges;
#               var nodeColors;
#               var originalNodes;
#               var network;
#               var container;
#               var options, data;
#               var filter = {
#                   item : '',
#                   property : '',
#                   value : []
#               };
#
#
#
#
#
#               // This method is responsible for drawing the graph, returns the drawn network
#               function drawGraph() {
#                   var container = document.getElementById('mynetwork');
#
#
#
#                   // parsing and collecting nodes and edges from the python
#                   nodes = new vis.DataSet([{"color": "#97c2fc", "font": {"color": "white"}, "id": 0, "label": 0, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 1, "label": 1, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 19, "label": 19, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 2, "label": 2, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 18, "label": 18, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 3, "label": 3, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 4, "label": 4, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 5, "label": 5, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 6, "label": 6, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 7, "label": 7, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 8, "label": 8, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 12, "label": 12, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 9, "label": 9, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 10, "label": 10, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 11, "label": 11, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 13, "label": 13, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 14, "label": 14, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 15, "label": 15, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 16, "label": 16, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 17, "label": 17, "shape": "dot", "size": 10}]);
#                   edges = new vis.DataSet([{"from": 0, "to": 1, "width": 1}, {"from": 0, "to": 19, "width": 1}, {"from": 0, "to": 2, "width": 1}, {"from": 0, "to": 18, "width": 1}, {"from": 1, "to": 2, "width": 1}, {"from": 1, "to": 3, "width": 1}, {"from": 2, "to": 3, "width": 1}, {"from": 2, "to": 4, "width": 1}, {"from": 3, "to": 4, "width": 1}, {"from": 3, "to": 5, "width": 1}, {"from": 3, "to": 19, "width": 1}, {"from": 4, "to": 5, "width": 1}, {"from": 4, "to": 6, "width": 1}, {"from": 5, "to": 6, "width": 1}, {"from": 5, "to": 7, "width": 1}, {"from": 6, "to": 7, "width": 1}, {"from": 6, "to": 8, "width": 1}, {"from": 7, "to": 8, "width": 1}, {"from": 7, "to": 18, "width": 1}, {"from": 7, "to": 12, "width": 1}, {"from": 8, "to": 9, "width": 1}, {"from": 8, "to": 10, "width": 1}, {"from": 9, "to": 10, "width": 1}, {"from": 9, "to": 11, "width": 1}, {"from": 10, "to": 11, "width": 1}, {"from": 10, "to": 12, "width": 1}, {"from": 11, "to": 12, "width": 1}, {"from": 11, "to": 13, "width": 1}, {"from": 12, "to": 13, "width": 1}, {"from": 12, "to": 14, "width": 1}, {"from": 13, "to": 14, "width": 1}, {"from": 13, "to": 15, "width": 1}, {"from": 14, "to": 15, "width": 1}, {"from": 14, "to": 16, "width": 1}, {"from": 15, "to": 16, "width": 1}, {"from": 15, "to": 17, "width": 1}, {"from": 16, "to": 17, "width": 1}, {"from": 16, "to": 18, "width": 1}, {"from": 17, "to": 18, "width": 1}, {"from": 17, "to": 19, "width": 1}]);
#
#                   nodeColors = {};
#                   allNodes = nodes.get({ returnType: "Object" });
#                   for (nodeId in allNodes) {
#                     nodeColors[nodeId] = allNodes[nodeId].color;
#                   }
#                   allEdges = edges.get({ returnType: "Object" });
#                   // adding nodes and edges to the graph
#                   data = {nodes: nodes, edges: edges};
#
#                   var options = {
#     "configure": {
#         "enabled": false
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": true,
#             "type": "dynamic"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "enabled": true,
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
#
#
#
#
#
#
#                   network = new vis.Network(container, data, options);
#
#
#
#
#
#
#
#
#
#
#                   return network;
#
#               }
#               drawGraph();
#         </script>
#     </body>
# </html>

# %%
# Generate and visualize a Random Regular graph
generator.generate_random_regular(n=20, d=3)
print(generator.get_graph_info())
generator.visualize_graph("Random Regular Graph")
generator.display_graph_html()
# Out:
# Graph Type: Random-Regular_n20_d3
# Number of nodes: 20
# Number of edges: 30
# Average clustering coefficient: 0.1000
# Average shortest path length: 2.7000
#
# Graph plot saved as: graphs/Random-Regular_n20_d3_plot.png
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script src="lib/bindings/utils.js"></script>
#             <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/dist/vis-network.min.css" integrity="sha512-WgxfT5LWjfszlPHXRmBWHkV2eceiWTOBvrKCNbdgDYTHrT2AeLCGbF4sZlZw3UMN3WtL0tGUoIAKsu8mllg/XA==" crossorigin="anonymous" referrerpolicy="no-referrer" />
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/vis-network.min.js" integrity="sha512-LnvoEWDFrqGHlHmDD2101OrLcbsfkrzoSpvtSQtxK3RMnRV0eOkhhBN2dXHKRrUU8p2DGRTk35n4O8nWSVe1mQ==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#
#
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#         <link
#           href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/css/bootstrap.min.css"
#           rel="stylesheet"
#           integrity="sha384-eOJMYsd53ii+scO/bJGFsiCZc+5NDVN2yr8+0RDqr0Ql0h+rP48ckxlpbzKgwra6"
#           crossorigin="anonymous"
#         />
#         <script
#           src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/js/bootstrap.bundle.min.js"
#           integrity="sha384-JEW9xMcG8R+pH31jmWH6WWP0WintQrMb4s7ZOdauHnUtxwoG2vI5DkLtS3qm9Ekf"
#           crossorigin="anonymous"
#         ></script>
#
#
#         <center>
#           <h1></h1>
#         </center>
#         <style type="text/css">
#
#              #mynetwork {
#                  width: 100%;
#                  height: 500px;
#                  background-color: #222222;
#                  border: 1px solid lightgray;
#                  position: relative;
#                  float: left;
#              }
#
#
#
#
#
#
#         </style>
#     </head>
#
#
#     <body>
#         <div class="card" style="width: 100%">
#
#
#             <div id="mynetwork" class="card-body"></div>
#         </div>
#
#
#
#
#         <script type="text/javascript">
#
#               // initialize global variables.
#               var edges;
#               var nodes;
#               var allNodes;
#               var allEdges;
#               var nodeColors;
#               var originalNodes;
#               var network;
#               var container;
#               var options, data;
#               var filter = {
#                   item : '',
#                   property : '',
#                   value : []
#               };
#
#
#
#
#
#               // This method is responsible for drawing the graph, returns the drawn network
#               function drawGraph() {
#                   var container = document.getElementById('mynetwork');
#
#
#
#                   // parsing and collecting nodes and edges from the python
#                   nodes = new vis.DataSet([{"color": "#97c2fc", "font": {"color": "white"}, "id": 6, "label": 6, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 12, "label": 12, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 7, "label": 7, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 13, "label": 13, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 16, "label": 16, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 17, "label": 17, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 14, "label": 14, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 3, "label": 3, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 10, "label": 10, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 9, "label": 9, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 0, "label": 0, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 18, "label": 18, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 1, "label": 1, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 15, "label": 15, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 5, "label": 5, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 19, "label": 19, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 4, "label": 4, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 11, "label": 11, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 2, "label": 2, "shape": "dot", "size": 10}, {"color": "#97c2fc", "font": {"color": "white"}, "id": 8, "label": 8, "shape": "dot", "size": 10}]);
#                   edges = new vis.DataSet([{"from": 6, "to": 12, "width": 1}, {"from": 6, "to": 7, "width": 1}, {"from": 6, "to": 13, "width": 1}, {"from": 12, "to": 16, "width": 1}, {"from": 12, "to": 17, "width": 1}, {"from": 16, "to": 14, "width": 1}, {"from": 16, "to": 13, "width": 1}, {"from": 3, "to": 10, "width": 1}, {"from": 3, "to": 9, "width": 1}, {"from": 3, "to": 0, "width": 1}, {"from": 10, "to": 18, "width": 1}, {"from": 10, "to": 1, "width": 1}, {"from": 14, "to": 0, "width": 1}, {"from": 14, "to": 15, "width": 1}, {"from": 5, "to": 19, "width": 1}, {"from": 5, "to": 4, "width": 1}, {"from": 5, "to": 17, "width": 1}, {"from": 19, "to": 15, "width": 1}, {"from": 19, "to": 1, "width": 1}, {"from": 9, "to": 11, "width": 1}, {"from": 9, "to": 2, "width": 1}, {"from": 11, "to": 17, "width": 1}, {"from": 11, "to": 15, "width": 1}, {"from": 0, "to": 8, "width": 1}, {"from": 8, "to": 4, "width": 1}, {"from": 8, "to": 7, "width": 1}, {"from": 18, "to": 1, "width": 1}, {"from": 18, "to": 2, "width": 1}, {"from": 7, "to": 13, "width": 1}, {"from": 4, "to": 2, "width": 1}]);
#
#                   nodeColors = {};
#                   allNodes = nodes.get({ returnType: "Object" });
#                   for (nodeId in allNodes) {
#                     nodeColors[nodeId] = allNodes[nodeId].color;
#                   }
#                   allEdges = edges.get({ returnType: "Object" });
#                   // adding nodes and edges to the graph
#                   data = {nodes: nodes, edges: edges};
#
#                   var options = {
#     "configure": {
#         "enabled": false
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": true,
#             "type": "dynamic"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "enabled": true,
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
#
#
#
#
#
#
#                   network = new vis.Network(container, data, options);
#
#
#
#
#
#
#
#
#
#
#                   return network;
#
#               }
#               drawGraph();
#         </script>
#     </body>
# </html>
